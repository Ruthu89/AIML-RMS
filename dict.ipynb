# %%
dict={"id":1,"name":"ruthu","age":30}
dict.get("id")
# Out:
# 1

# %%
dict["name"]
# Out:
# 'ruthu'

# %%
dict["id"]
# Out:
# 1

# %%
dict.update({"place":"banglore"})

# %%
dict
# Out:
# {'id': 1, 'name': 'ruthu', 'age': 30, 'place': 'banglore'}

# %%
dict.popitem()
dict
# Out:
# {'id': 1, 'name': 'ruthu', 'age': 30}

# %%
dict.pop("id")
dict
# Out:
# {'name': 'ruthu', 'age': 30}

# %%
A={1,2,3,4}
B={3,4,5,6}

# %%
print("Union:",A.union(B))
# Out:
# Union: {1, 2, 3, 4, 5, 6}

# %%
print("Intersection:",A.intersection(B))
# Out:
# Intersection: {3, 4}

# %%
print("Difference:",A-B)
# Out:
# Difference: {1, 2}

# %%
print("Difference:",B-A)
# Out:
# Difference: {5, 6}

# %%
A.add(7)
A
# Out:
# {1, 2, 3, 4, 7}
