# %%
#pandas

# %%
import pandas as pd
import numpy as np

# %%
data=pd.Series([1,2,3,4])
data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
data=pd.Series([1,2,3,4],index=["a","b","c","d"])
data
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
data.name="Numbers"
data
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: Numbers, dtype: int64

# %%
data.size
# Out:
# 4

# %%
len(data)
# Out:
# 4

# %%
data.shape
# Out:
# (4,)

# %%
data.values
# Out:
# array([1, 2, 3, 4])

# %%
data["b"],data["a"],data["c"]
# Out:
# (np.int64(2), np.int64(1), np.int64(3))

# %%
data.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
data.loc["a"::2],data.iloc[3]
# Out:
# (a    1
#  c    3
#  Name: Numbers, dtype: int64,
#  np.int64(4))

# %%
data.loc["a"::2],data.iloc[1]
# Out:
# (a    1
#  c    3
#  Name: Numbers, dtype: int64,
#  np.int64(2))

# %%
data.loc[["a","b","c"]],data.iloc[3]
# Out:
# (a    1
#  b    2
#  c    3
#  Name: Numbers, dtype: int64,
#  np.int64(4))

# %%
#data frames

# %%
dictionary = {
     "usn":[1,2,3,4],
    "name":["ruthu","uujgooooooo","ghghhhhhh","fguyegggggggg"],
    "branch":["CSE","ise","aiml","eee"],
    "age":[22,21,32,44]
}

# %%
df = pd.DataFrame(dictionary)
df
# Out:
#    usn           name branch  age
# 0    1          ruthu    CSE   22
# 1    2    uujgooooooo    ise   21
# 2    3      ghghhhhhh   aiml   32
# 3    4  fguyegggggggg    eee   44

# %%
d=pd.read_csv(r"C:\Users\ruthu\Downloads\sample.csv")
d
# Out:
#     Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 0            0    101    Ram         IT   25   50000           2  2021-01-15
# 1            1    102  Shyam         HR   30   45000           5  2019-03-10
# 2            2    103  Geeta    Finance   28   60000           4  2020-07-22
# 3            3    104  Anita         IT   35   75000          10  2015-09-30
# 4            4    105  Kiran         HR   32   52000           7  2018-06-12
# 5            5    106   John    Finance   29   58000           3  2021-11-05
# 6            6    107  Meena         IT   41   82000          15  2010-04-18
# 7            7    108  David         HR   26   48000           2  2022-02-14
# 8            8    109   Sara    Finance   38   61000          12  2013-12-01
# 9            9    110  Arjun         IT   27   54000           4  2020-08-19
# 10          10    111   Ravi         HR   33   47000           6  2017-05-23
# ...

# %%
d.tail(10)
# Out:
#     Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 10          10    111   Ravi         HR   33   47000           6  2017-05-23
# 11          11    112  Priya    Finance   31   59000           5  2019-09-17
# 12          12    113  Kunal         IT   45   90000          18  2008-03-11
# 13          13    114  Sneha         HR   29   51000           3  2021-07-29
# 14          14    115  Vijay    Finance   36   62000          11  2014-01-10
# 15          15    116   Neha         IT   40   88000          14  2011-10-21
# 16          16    117   Amit         HR   34   53000           8  2016-04-05
# 17          17    118  Pooja    Finance   30   57000           6  2018-12-12
# 18          18    119  Rahul         IT   28   56000           4  2020-02-28
# 19          19    120  Divya         HR   37   49500           9  2015-06-30
#
#          City  PerformanceScore
# 10     Mumbai               3.6
# 11      Delhi               4.4
# ...

# %%
d.describe()
# Out:
#        Unnamed: 0      EmpID        Age        Salary  Experience  \
# count    20.00000   20.00000  20.000000     20.000000   20.000000
# mean      9.50000  110.50000  32.700000  59875.000000    7.400000
# std       5.91608    5.91608   5.449288  13388.796377    4.615762
# min       0.00000  101.00000  25.000000  45000.000000    2.000000
# 25%       4.75000  105.75000  28.750000  50750.000000    4.000000
# 50%       9.50000  110.50000  31.500000  56500.000000    6.000000
# 75%      14.25000  115.25000  36.250000  61250.000000   10.250000
# max      19.00000  120.00000  45.000000  90000.000000   18.000000
#
#        PerformanceScore
# count         20.000000
# mean           4.190000
# std            0.415363
# min            3.500000
# 25%            3.900000
# 50%            4.150000
# 75%            4.425000
# max            4.900000

# %%
d.tail()
# Out:
#     Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 15          15    116   Neha         IT   40   88000          14  2011-10-21
# 16          16    117   Amit         HR   34   53000           8  2016-04-05
# 17          17    118  Pooja    Finance   30   57000           6  2018-12-12
# 18          18    119  Rahul         IT   28   56000           4  2020-02-28
# 19          19    120  Divya         HR   37   49500           9  2015-06-30
#
#          City  PerformanceScore
# 15  Bangalore               4.7
# 16     Mumbai               4.0
# 17      Delhi               4.1
# 18  Bangalore               3.9
# 19     Mumbai               4.3

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20 non-null     int64
#  1   EmpID             20 non-null     int64
#  2   Name              20 non-null     object
#  3   Department        20 non-null     object
#  4   Age               20 non-null     int64
#  5   Salary            20 non-null     int64
#  6   Experience        20 non-null     int64
#  7   JoiningDate       20 non-null     object
#  8   City              20 non-null     object
#  9   PerformanceScore  20 non-null     float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 1.7+ KB

# %%
d.shape
# Out:
# (20, 10)

# %%
d.sample()
# Out:
#    Unnamed: 0  EmpID  Name Department  Age  Salary  Experience JoiningDate  \
# 8           8    109  Sara    Finance   38   61000          12  2013-12-01
#
#     City  PerformanceScore
# 8  Delhi               4.3

# %%
d.head()
d
# Out:
#     Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 0            0    101    Ram         IT   25   50000           2  2021-01-15
# 1            1    102  Shyam         HR   30   45000           5  2019-03-10
# 2            2    103  Geeta    Finance   28   60000           4  2020-07-22
# 3            3    104  Anita         IT   35   75000          10  2015-09-30
# 4            4    105  Kiran         HR   32   52000           7  2018-06-12
# 5            5    106   John    Finance   29   58000           3  2021-11-05
# 6            6    107  Meena         IT   41   82000          15  2010-04-18
# 7            7    108  David         HR   26   48000           2  2022-02-14
# 8            8    109   Sara    Finance   38   61000          12  2013-12-01
# 9            9    110  Arjun         IT   27   54000           4  2020-08-19
# 10          10    111   Ravi         HR   33   47000           6  2017-05-23
# ...

# %%
d["Name"]
# Out:
# 0       Ram
# 1     Shyam
# 2     Geeta
# 3     Anita
# 4     Kiran
# 5      John
# 6     Meena
# 7     David
# 8      Sara
# 9     Arjun
# 10     Ravi
# 11    Priya
# 12    Kunal
# 13    Sneha
# 14    Vijay
# 15     Neha
# 16     Amit
# 17    Pooja
# 18    Rahul
# 19    Divya
# Name: Name, dtype: object

# %%
d.Name
# Out:
# 0       Ram
# 1     Shyam
# 2     Geeta
# 3     Anita
# 4     Kiran
# 5      John
# 6     Meena
# 7     David
# 8      Sara
# 9     Arjun
# 10     Ravi
# 11    Priya
# 12    Kunal
# 13    Sneha
# 14    Vijay
# 15     Neha
# 16     Amit
# 17    Pooja
# 18    Rahul
# 19    Divya
# Name: Name, dtype: object

# %%
d[["Name","Department","Salary","Experience"]]
# Out:
#      Name Department  Salary  Experience
# 0     Ram         IT   50000           2
# 1   Shyam         HR   45000           5
# 2   Geeta    Finance   60000           4
# 3   Anita         IT   75000          10
# 4   Kiran         HR   52000           7
# 5    John    Finance   58000           3
# 6   Meena         IT   82000          15
# 7   David         HR   48000           2
# 8    Sara    Finance   61000          12
# 9   Arjun         IT   54000           4
# 10   Ravi         HR   47000           6
# 11  Priya    Finance   59000           5
# 12  Kunal         IT   90000          18
# 13  Sneha         HR   51000           3
# 14  Vijay    Finance   62000          11
# 15   Neha         IT   88000          14
# 16   Amit         HR   53000           8
# 17  Pooja    Finance   57000           6
# 18  Rahul         IT   56000           4
# 19  Divya         HR   49500           9

# %%
d[["Name","Department","Salary","Experience"]].head()
# Out:
#     Name Department  Salary  Experience
# 0    Ram         IT   50000           2
# 1  Shyam         HR   45000           5
# 2  Geeta    Finance   60000           4
# 3  Anita         IT   75000          10
# 4  Kiran         HR   52000           7

# %%
type(d.Name)
# Out:
# pandas.core.series.Series

# %%
du=pd.read_csv(r"C:\Users\ruthu\Downloads\test2.csv")
du
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
du.isnull()
# Out:
#    Unnamed: 0   Name    Age  Department  Salary
# 0       False  False  False       False   False
# 1       False  False  False       False   False
# 2       False  False  False       False   False
# 3       False  False   True       False   False
# 4       False  False  False       False    True
# 5       False  False  False       False   False

# %%
du.loc[ "1":"3", "Name": "Age"]
# Out:
#       Name   Age
# 1      Bob  30.0
# 2  Charlie  35.0
# 3    David   NaN

# %%
du.isnull().
# Out:
# Unnamed: 0    0
# Name          0
# Age           1
# Department    0
# Salary        1
# dtype: int64

# %%
du.loc[ :,:]
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
du.loc[1:3,"Name":"Department"]
# Out:
#       Name   Age Department
# 1      Bob  30.0         IT
# 2  Charlie  35.0    Finance
# 3    David   NaN         IT

# %%
du.iloc[1:4, 1:4]
# Out:
#       Name   Age Department
# 1      Bob  30.0         IT
# 2  Charlie  35.0    Finance
# 3    David   NaN         IT

# %%
du.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
du.rename(columns={"Name":"N","Age":"A","Department":"D"},inplace=True)

# %%
du
# Out:
#    Unnamed: 0        N     A        D   Salary
# 0           0    Alice  25.0       HR  50000.0
# 1           1      Bob  30.0       IT  60000.0
# 2           2  Charlie  35.0  Finance  70000.0
# 3           3    David   NaN       IT  62000.0
# 4           4      Eve  29.0       HR      NaN
# 5           5    Alice  25.0       HR  50000.0

# %%
du=pd.read_csv(r"C:\Users\ruthu\Downloads\test2.csv")
du
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
du.rename(columns={"Name":"N","Age":"A","Department":"D"}
          ,inplace=True)
du
# Out:
#          N     A        D   Salary
# 0    Alice  25.0       HR  50000.0
# 1      Bob  30.0       IT  60000.0
# 2  Charlie  35.0  Finance  70000.0
# 3    David   NaN       IT  62000.0
# 4      Eve  29.0       HR      NaN
# 5    Alice  25.0       HR  50000.0

# %%
du=pd.read_csv(r"C:\Users\ruthu\Downloads\test2.csv")
du
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
du.drop('Unnamed: 0',axis=1,inplace=True)
du
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
du.drop('Name',axis=1,inplace=True)
du
# Out:
#     Age Department   Salary
# 0  25.0         HR  50000.0
# 1  30.0         IT  60000.0
# 2  35.0    Finance  70000.0
# 3   NaN         IT  62000.0
# 4  29.0         HR      NaN
# 5  25.0         HR  50000.0

# %%
du["updated_salary"]=du["Salary"]+6000
du
# Out:
#     Age Department   Salary  updated_salary
# 0  25.0         HR  50000.0         56000.0
# 1  30.0         IT  60000.0         66000.0
# 2  35.0    Finance  70000.0         76000.0
# 3   NaN         IT  62000.0         68000.0
# 4  29.0         HR      NaN             NaN
# 5  25.0         HR  50000.0         56000.0

# %%
du["updated_salary_2"]=du["Salary"].map(lambda x:x+40900)
du
# Out:
#     Age Department   Salary  updated_salary  updated_salary_2
# 0  25.0         HR  50000.0         56000.0           90900.0
# 1  30.0         IT  60000.0         66000.0          100900.0
# 2  35.0    Finance  70000.0         76000.0          110900.0
# 3   NaN         IT  62000.0         68000.0          102900.0
# 4  29.0         HR      NaN             NaN               NaN
# 5  25.0         HR  50000.0         56000.0           90900.0

# %%
du.Age.dtype #cant add int value coz it has null values
# Out:
# dtype('float64')

# %%
du.dropna(inplace=True)

# %%
du
# Out:
#     Age Department   Salary  updated_salary  updated_salary_2
# 0  25.0         HR  50000.0         56000.0           90900.0
# 1  30.0         IT  60000.0         66000.0          100900.0
# 2  35.0    Finance  70000.0         76000.0          110900.0
# 5  25.0         HR  50000.0         56000.0           90900.0

# %%
du.isnull().sum()
# Out:
# Age                 0
# Department          0
# Salary              0
# updated_salary      0
# updated_salary_2    0
# dtype: int64

# %%
du["Age"]=du.Age.astype("int")

# %%
du
# Out:
#    Age Department   Salary  updated_salary  updated_salary_2
# 0   25         HR  50000.0         56000.0           90900.0
# 1   30         IT  60000.0         66000.0          100900.0
# 2   35    Finance  70000.0         76000.0          110900.0
# 5   25         HR  50000.0         56000.0           90900.0

# %%
du["Age"]>25
# Out:
# 0    False
# 1     True
# 2     True
# 5    False
# Name: Age, dtype: bool

# %%
du[du["Age"]>25]
# Out:
#    Age Department   Salary  updated_salary  updated_salary_2
# 1   30         IT  60000.0         66000.0          100900.0
# 2   35    Finance  70000.0         76000.0          110900.0

# %%
du=pd.read_csv(r"C:\Users\ruthu\Downloads\test2.csv")
du
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
du.isnull().sum()
# Out:
# Unnamed: 0    0
# Name          0
# Age           1
# Department    0
# Salary        1
# dtype: int64

# %%
du["Age"].mean()
# Out:
# np.float64(28.8)

# %%
du["Age"]=du["Age"].fillna(value=du["Age"].mean())

# %%
du
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  28.8         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
du["Salary"].mean()
# Out:
# np.float64(58400.0)

# %%
du["Salary"]=du["Salary"].fillna(value=du["Salary"].mean())
du
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  28.8         IT  62000.0
# 4           4      Eve  29.0         HR  58400.0
# 5           5    Alice  25.0         HR  50000.0

# %%
du["Department"].value_counts()
# Out:
# Department
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
du["Salary"].value_counts()
# Out:
# Salary
# 50000.0    2
# 60000.0    1
# 70000.0    1
# 62000.0    1
# 58400.0    1
# Name: count, dtype: int64

# %%
du=pd.read_csv(r"C:\Users\ruthu\Downloads\test2.csv")
du
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
du["Age"]=du["Age"].fillna(method="ffill")  #forward fill
du["Salary"]=du["Salary"].fillna(method="bfill") #backward fill
du
# Out:
# C:\Users\ruthu\AppData\Local\Temp\ipykernel_3848\3692182043.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   du["Age"]=du["Age"].fillna(method="ffill")  #forward fill
# C:\Users\ruthu\AppData\Local\Temp\ipykernel_3848\3692182043.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   du["Salary"]=du["Salary"].fillna(method="bfill") #backward fill
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  35.0         IT  62000.0
# 4           4      Eve  29.0         HR  50000.0
# 5           5    Alice  25.0         HR  50000.0

# %%
du.Department.ffill()
# Out:
# 0         HR
# 1         IT
# 2    Finance
# 3         IT
# 4         HR
# 5         HR
# Name: Department, dtype: object

# %%
du.Age.ffill()
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    35.0
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
du["updated_salary"]=du["Salary"].apply(lambda x:x+40900)
du
# Out:
#    Unnamed: 0     Name   Age Department   Salary  updated_salary_2  \
# 0           0    Alice  25.0         HR  50000.0           90900.0
# 1           1      Bob  30.0         IT  60000.0          100900.0
# 2           2  Charlie  35.0    Finance  70000.0          110900.0
# 3           3    David  35.0         IT  62000.0          102900.0
# 4           4      Eve  29.0         HR  50000.0           90900.0
# 5           5    Alice  25.0         HR  50000.0           90900.0
#
#    updated_salary
# 0         90900.0
# 1        100900.0
# 2        110900.0
# 3        102900.0
# 4         90900.0
# 5         90900.0

# %%
du["Level"]= du.apply(lambda s:"High" if s ["updated_salary"] > 100000 else "Low", axis=1)

# %%
du
# Out:
#    Unnamed: 0     Name   Age Department   Salary  updated_salary_2  \
# 0           0    Alice  25.0         HR  50000.0           90900.0
# 1           1      Bob  30.0         IT  60000.0          100900.0
# 2           2  Charlie  35.0    Finance  70000.0          110900.0
# 3           3    David  35.0         IT  62000.0          102900.0
# 4           4      Eve  29.0         HR  50000.0           90900.0
# 5           5    Alice  25.0         HR  50000.0           90900.0
#
#    updated_salary Level
# 0         90900.0   Low
# 1        100900.0  High
# 2        110900.0  High
# 3        102900.0  High
# 4         90900.0   Low
# 5         90900.0   Low

# %%
du.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance    70000.0
# HR         50000.0
# IT         61000.0
# Name: Salary, dtype: float64
