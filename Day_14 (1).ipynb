# %%
#ml
#supervised - labeled, 
           #regression - linear,polinomial,SVR,dicision tree, random forest,logistic
#unsupervised - unlabed, 
            #clustering(grouping) - hierarchical, DB SCAN, GMM,K Means

# %%
#Linear Regression(used only in continuous value prediction)
#formula y=mx+c
#m- slope
#c- intercept, straight line
#x- independent variable

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import boxcox
z=pd.read_csv(r"C:\Users\ruthu\Downloads\housing.csv")
z
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
z.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.histplot(z.population)
plt.show()

# %%
z.population.skew()
# Out:
# np.float64(4.935858226727124)

# %%
z.total_bedrooms=z.total_bedrooms.fillna(value=z.total_bedrooms.mean())

# %%
z
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
z.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
z.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
z.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
z.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        419.266592   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
z.shape
# Out:
# (20640, 10)

# %%
z = z.drop_duplicates()

# %%
z
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
z
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
z["total_rooms"] = pd.to_numeric(z["total_rooms"], errors="coerce")
z
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
z.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
plt.figure()
sns.histplot(z.total_rooms)
plt.show()

# %%
z.total_rooms.skew()
# Out:
# np.float64(4.147343450632158)

# %%
z.shape
# Out:
# (20640, 10)

# %%
plt.figure()
sns.histplot(z.housing_median_age)
plt.show()

# %%
z.housing_median_age.skew()
# Out:
# np.float64(0.06033063759913685)

# %%
plt.figure()
sns.histplot(z.total_bedrooms)
plt.show()

# %%
z.total_bedrooms.skew()
# Out:
# np.float64(3.4770233756335114)

# %%
plt.figure()
sns.histplot(z.population)
plt.show()

# %%
z.population.skew()
# Out:
# np.float64(4.935858226727124)

# %%
plt.figure()
sns.histplot(z.median_income)
plt.show()

# %%
z.median_income.skew()
# Out:
# np.float64(1.6466567021344465)

# %%
plt.figure()
sns.pairplot(z)

# %%
num_z = z.select_dtypes(include='number')
num_z.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %%
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069260 -0.066658           -0.318998     0.927253
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069260    0.099773    0.055310      -0.015176
# latitude                 -0.066658   -0.108785   -0.071035      -0.079809
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train, y_test=train_test_split9x,y,test_size=2.0,random_start

# %%
from sklearn.preprocessing import StandardScaler , MinMaxScaler
scaler = StandardScaler()

# %%
z["longitude"] = scaler.fit_transform(z[["longitude"]])
z["latitude"] = scaler.fit_transform(z[["latitude"]])
z["housing_median_age"] = scaler.fit_transform(z[["housing_median_age"]])
z["total_rooms"] = scaler.fit_transform(z[["total_rooms"]])
z["total_bedrooms"] = scaler.fit_transform(z[["total_bedrooms"]])
z["population"] = scaler.fit_transform(z[["population"]])
z["households"] = scaler.fit_transform(z[["households"]])
z["median_income"] = scaler.fit_transform(z[["median_income"]])

# %%
z.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0  -1.327835  1.052548            0.982143    -0.804819       -0.975228
# 1  -1.322844  1.043185           -0.607019     2.045890        1.355088
# 2  -1.332827  1.038503            1.856182    -0.535746       -0.829732
# 3  -1.337818  1.038503            1.856182    -0.624215       -0.722399
# 4  -1.337818  1.038503            1.856182    -0.462404       -0.615066
#
#    population  households  median_income  median_house_value ocean_proximity
# 0   -0.974429   -0.977033       2.344766            452600.0        NEAR BAY
# 1    0.861439    1.669961       2.332238            358500.0        NEAR BAY
# 2   -0.820777   -0.843637       1.782699            352100.0        NEAR BAY
# 3   -0.766028   -0.733781       0.932968            341300.0        NEAR BAY
# 4   -0.759847   -0.629157      -0.012881            342200.0        NEAR BAY

# %%
z.hist(figsize=(10,8))
plt.show()

# %%
x = z[["longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income"]]
y = z[["median_house_value"]]

# %%
x.shape, y.shape
# Out:
# ((20640, 8), (20640, 1))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train, y_test = train_test_split(x,y, test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((16512, 8), (4128, 8))

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.metrics import mean_squared_error , r2_score

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_,model.coef_
# Out:
# (array([206760.58213456]),
#  array([[-85413.28005747, -90669.13624699,  14885.95835764,
#          -17862.58294108,  48742.80673019, -43589.91735845,
#           17717.71485854,  77013.87535191]]))

# %%
predicted_val = model.predict(x_test)

# %%
predicted_val
# Out:
# array([[ 75696.33491152],
#        [166304.33789222],
#        [265032.93786054],
#        ...,
#        [439178.19697502],
#        [130408.85287046],
#        [175272.25192552]], shape=(4128, 1))

# %%
mean_squared_error(y_test , predicted_val)
# Out:
# 5052953703.9016285

# %%
r2_score(y_test , predicted_val)
# Out:
# 0.6143987268246024
